# %%
import re
a="Hello Everyone"
b=re.search(r'\s',a)
print("The position of white space is:",b.start())
# Out:
# The position of white space is: 5

# %%
import re
s=re.search('r',"Good Morning Everyone")
print(s.start())
# Out:
# 7

# %%
import re
a="Good Morning"
b=re.match(r"Good",a)
print(b)
# Out:
# <re.Match object; span=(0, 4), match='Good'>

# %%
import re
str="Good Morning Everyone"
a=re.findall('o',str)
print(a)
# Out:
# ['o', 'o', 'o', 'o']

# %%
import re
str="Good Morning Everyone"
a=re.split("o",str)
print("The string is split",a)
# Out:
# The string is split ['Good Morning ', 'veryone']

# %%
m=re.match('H',a)       #match method only find starting character
if m:
    print(m.group())

else:
    print("Not found")
# Out:
# H
