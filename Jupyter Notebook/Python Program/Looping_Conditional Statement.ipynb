# %%
print("1 While Loop")
print("2 For Loop")
choice=int(input(" Enter Your Choice:"))
if(choice == 1):
    a=1
    while(a<5):
        print(a)
        a+=1

elif(choice == 2):
    for x in range(1,6,1):
        print(x)

else:
    print("OK")
# Out:
# 1 While Loop
# 2 For Loop
#  Enter Your Choice: 2
# 1
# 2
# 3
# 4
# 5

# %%
a=int(input("Enter the first value:"))
b=int(input("Enter the second value:"))
c=a+b
print("The addition of two variable is:",c)
# Out:
# Enter the first value: 21
# Enter the second value: 2
# The addition of two variable is: 23
