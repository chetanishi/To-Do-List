# %%
str=['1','2','3','4','5','6']
result=map(int, str)
print(list(result))
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list=[1,2,3,4,5]
list1=[6,7,8,9,10]
result=tuple(map(lambda a,b: a+b, list,list1))
print(result)
# Out:
# (7, 9, 11, 13, 15)

# %%
number=range(1,10)
even_number=[x**2 for x in number ]
print("The range of the number is:",tuple(number))
print("The even number is:",even_number)
# Out:
# The range of the number is: (1, 2, 3, 4, 5, 6, 7, 8, 9)
# The even number is: [2, 4, 6, 8, 10, 12, 14, 16, 18]

# %%
keys=["Name","Hobby","Age"]
values=["Chetan","Cricket",22]
dict={keys[i]: values[i] for i in range(len(keys))}
print(dict)
# Out:
# {'Name': 'Chetan', 'Hobby': 'Cricket', 'Age': 22}
