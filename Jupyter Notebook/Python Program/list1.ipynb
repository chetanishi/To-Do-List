# %%
list=[5,4,1,8,2,3]
print(list)
# Out:
# [5, 4, 1, 8, 2, 3]

# %%
list.sort()
print(list)
# Out:
# [1, 2, 3, 4, 5, 8]

# %%
print(min(list))
# Out:
# 1

# %%
print(max(list))
# Out:
# 8

# %%
print(len(list))
# Out:
# 6

# %%
list.append(10)
print(list)
# Out:
# [1, 2, 3, 4, 5, 8, 10]

# %%
list.insert(1,11)
print(list)
# Out:
# [1, 11, 2, 3, 4, 5, 8, 10]

# %%
print(list[1])
# Out:
# 11

# %%
print(list[-1])
# Out:
# 10

# %%
list[1]=20
print(list)
# Out:
# [1, 20, 2, 3, 4, 5, 8, 10]
