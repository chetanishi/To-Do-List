# %%
print("1 for loop")
print("2 while loop")
ch=int(input("Enter a number"))
if ch==1:
    for x in range(1,5):
        print(x)

elif ch==2:
    count=0
    while(0<5):
        count+=1
        print(count)
else:
    print("Number not match")
# Out:
# 1 for loop
# 2 while loop
# Enter a number 2
# 0
# 1
# 2
# 3
# 4
