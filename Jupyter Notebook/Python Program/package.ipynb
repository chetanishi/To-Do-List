# %%
mkdir math1

# %%
# %%writefile math1/__init__.py
# Out:
# UsageError: %%writefile is a cell magic, but the cell body is empty.

# %%
# %%writefile math1/math_op.py
def add(a,b):
    return a+b
def sub(a,b):
    return a-b
# Out:
# Overwriting math1/math_op.py

# %%
from math1 import math_op

print("The addition of two no",math_op.add(5,2))
print("The substraction of twno no:",math_op.sub(6,1))
# Out:
# The addition of two no 7
# The substraction of twno no: 5
