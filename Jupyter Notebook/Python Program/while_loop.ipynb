# %%
print("HELLO")
# Out:
# HELLO

# %%
a=1
while(a<10):
    a+=1
    print(a)
# Out:
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10

# %%
print("hello")
# Out:
# hello

# %%
a=10
b=56
c=a+b
print("The addition of two variable is:",c)
# Out:
# The addition of two variable is: 66
