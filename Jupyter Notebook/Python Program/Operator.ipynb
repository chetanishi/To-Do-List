# %%
a=30
b=20
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
print(a==b)
print(a!=b)
# Out:
# True
# False
# True
# False
# False
# True

# %%
a=10
print(a)
a+=1
print(a)
a*=2
print(a)
a/=2
print(a)
a-=1
print(a)
a%=2
print(a)
# Out:
# 10
# 11
# 22
# 11.0
# 10.0
# 0.0

# %%
a=10
b=20
print(a>b and a<b)
print(a>b or a<b)
print(not(a>b))
print(not(a<b))
# Out:
# False
# True
# True
# False
