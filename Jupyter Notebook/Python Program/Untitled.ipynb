# %%
mkdir chetu

# %%
# %%writefile chetu/__init__.py
# Out:
# UsageError: %%writefile is a cell magic, but the cell body is empty.

# %%
# %%writefile chetu/chetan1.py
def add(a,b):
    return a+b

def sub(a,b):
    return a-b

def mul(a,b):
    return a*b

def div(a,b):
    return a/b
# Out:
# Writing chetu/chetan1.py

# %%
from chetu import chetan1
a=10
b=5
print("The addition of two number:",chetan1.add(a,b))
print("The addition of two number:",chetan1.sub(a,b))
print("The addition of two number:",chetan1.mul(a,b))
print("The addition of two number:",chetan1.div(a,b))
# Out:
# The addition of two number: 15
# The addition of two number: 5
# The addition of two number: 50
# The addition of two number: 2.0
