# %%
add=lambda a,b:a+b
print(add(3,2))
# Out:
# 5

# %%
mul=lambda a,b:a*b
print(mul(2,5))
# Out:
# 10

# %%
div=lambda a,b:a/b
print(div(10,2))
# Out:
# 5.0

# %%
sub=lambda a,b:a-b
print(sub(5,2))
# Out:
# 3

# %%
mod=lambda a,b:a%b
print(mod(10,3))
# Out:
# 1
