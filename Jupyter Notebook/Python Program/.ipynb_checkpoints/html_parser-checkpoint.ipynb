# %%
from bs4 import BeautifulSoup

# %%
"""
<html>
<head>
<title>Hello Kalpya</title>
</head>
<body>
<h1>This is chetan</h1>

<h2>Shirpur</h2>
</body>
</html>"""

soup=BeautifulSoup(html_content,'html.parser')
title=soup.title.string
print("Title:",title)
heading=soup.h1.string
print("Heading:",heading)
p=soup.h2.string
print("Paragraph:",p)
# Out:
# Title: Hello Kalpya
# Heading: This is chetan
# Paragraph: Shirpur
