# %%
Lambda=lambda a,b:a*b
print(Lambda(3,2))
# Out:
# 6

# %%
li=['c','h','e','t','a','n']
result=list(filter(lambda a: a!='t',li))
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 li=['c','h','e','t','a','n']
# ----> 2 result=list(filter(lambda a: a!='t',li))
#       3 print(result)
#
# TypeError: 'list' object is not callable
