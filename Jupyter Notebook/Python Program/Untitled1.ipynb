# %%
with open('mca.txt','w') as file:
    file.write("This is mca file")

with open('mca.txt','r')as file:
    print("The content is in file:",file.read())

with open('mca.txt','a')as file:
    file.write("\nHello Everyone\n")
# Out:
# The content is in file: This is mca file

# %%
# Out:
# UsageError: %%writefile is a cell magic, but the cell body is empty.

# %%
# Out:
# Overwriting phy/math.py

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 4
#       2 a=10
#       3 b=3
# ----> 4 print("The addition:",phy.add(a,b))
#
# NameError: name 'phy' is not defined
